# %% [markdown]
# ### Adding Column to a Data Frame

# %%
import numpy as np  
import pandas as pd

# %%
data = {'Name': ['Jane', 'Princi', 'James', 'Fadi'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc'],
        'Score 1' : [56,86,77,45],
        'Score 2' : [50,96,60,30]}

df = pd.DataFrame(data)

# %%
print('Data Frame Before New Column:')
df.head()
# Out:
# Data Frame Before New Column:
#      Name  Height Qualification  Score 1  Score 2
# 0    Jane     5.1           Msc       56       50
# 1  Princi     6.2            MA       86       96
# 2   James     5.1           Msc       77       60
# 3    Fadi     5.2           Msc       45       30

# %%
addreess = ['NYC', 'NJ', 'CA', 'PA']

df('Address') == address
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 addreess = ['NYC', 'NJ', 'CA', 'PA']
#       2
# ----> 3 df('Address') == address
#
# TypeError: 'DataFrame' object is not callable

# %%
print('Before Column Add:')
df.head()
# Out:
# Before Column Add:
#      Name  Height Qualification  Score 1  Score 2
# 0    Jane     5.1           Msc       56       50
# 1  Princi     6.2            MA       86       96
# 2   James     5.1           Msc       77       60
# 3    Fadi     5.2           Msc       45       30

# %%
#ADD COLUMN using old column
df['Total Score'] = df['score 1'] + df['score 2']

print('After Column Add:')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Tatek\Desktop\Per Scholas\pandas_basics\pandasenv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df['Avg_Score'] = df['Total']/2
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Tatek\Desktop\Per Scholas\pandas_basics\pandasenv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %% [markdown]
# ### IMPORTING SPECIFIED and rEARRANGING THEM

# %%
data = {'Name': ['Jane', 'Princi', 'James', 'Fadi'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc'],
        'Score 1' : [56,86,77,45],
        'Score 2' : [50,96,60,30]}

df2 = pd.DataFrame(data, columns=['Score 1', 'Score 2','Name', 'Qualification'])
print(df2)
# Out:
#    Score 1  Score 2    Name Qualification
# 0       56       50    Jane           Msc
# 1       86       96  Princi            MA
# 2       77       60   James           Msc
# 3       45       30    Fadi           Msc

# %%
values = [['Rohan', 455], ['Elvish', 250], ['John', 495],
          ['Sai', 400], ['Eric', 350], ['Adam', 450]]

df3 = pd.DataFrame(values, columns=['Name', 'Univ_Marks'])

df3.head()
# Out:
#      Name  Univ_Marks
# 0   Rohan         455
# 1  Elvish         250
# 2    John         495
# 3     Sai         400
# 4    Eric         350

# %%
df['Percentage'] = (df['Univ_Marks'] / 500) * 100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Tatek\Desktop\Per Scholas\pandas_basics\pandasenv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %% [markdown]
# ### Using the  . insert() method to add a column

# %%
# UAsing insert allows you to get more central of where column is inserted
df3.insert(1, 'Age',[1000, 2000, 50, 60, 12, 13])

df3.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # UAsing insert allows you to get more central of where column is inserted
# ----> 2 df3.insert(1, 'Age',[1000, 2000, 50, 60, 12, 13])
#       3
#       4 df3.head()
#
# NameError: name 'df3' is not defined

# %%
df3 = df3.assign(location=['MiddleEarth', 'Georgia', 'NYC', 'CA', 'MA'])
df3.head()
